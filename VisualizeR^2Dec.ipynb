# %%
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing as prep

# %%
bitcoinBaseline = [0.808]
# order is txs, trends, posts, tweets
bitcoinChanges = [(0.808-0.677)/0.808, (0.808-0.334)/0.808, (0.808-0.336)/0.808, (0.808-0.385)/0.808, (0.808-0.026)/0.808, (0.808-0.266)/0.808, (0.808-0.378)/0.808]
print(["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
print(bitcoinChanges)
ax = plt.gca()
ax.set_ylim([0, 1])
plt.xlabel("Regressor")
plt.ylabel("Effect")
plt.title("Bitcoin")
plt.style.use('dark_background')
plt.bar([2.4, 4.8, 7.2, 9.6, 12.0, 14.4, 16.8], bitcoinChanges, tick_label = ["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
# Out:
# ['Transactions', 'Trends', 'Reddit', 'Twitter', 'AllTrends', 'AllReddit', 'AllTwitter']
# [0.16212871287128713, 0.5866336633663366, 0.5841584158415841, 0.5235148514851485, 0.9678217821782178, 0.6707920792079208, 0.5321782178217822]
# <BarContainer object of 7 artists>

# %%
etherBaseline = [0.902]
# order is txs, trends, posts, tweets
etherChanges = [0.900-0.617)/0.900, (0.900-0.398)/0.900, (0.831-0.262)/0.900, (0.900-0.154)/0.900, (0.900-0.138)/0.90(0, (0.900-0.219)/0.900, (0.900-0.216)/0.900]
print(["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
print(etherChanges)
ax = plt.gca()
ax.set_ylim([0, 1])
plt.xlabel("Regressor")
plt.ylabel("Effect")
plt.title("Ethereum")
plt.bar([2.4, 4.8, 7.2, 9.6, 12.0, 14.4, 16.8], etherChanges, tick_label = ["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
# Out:
# ['Transactions', 'Trends', 'Reddit', 'Twitter', 'AllTrends', 'AllReddit', 'AllTwitter']
# [0.31444444444444447, 0.5577777777777778, 0.6322222222222221, 0.8288888888888889, 0.8466666666666667, 0.7566666666666667, 0.76]
# <BarContainer object of 7 artists>

# %%
dogeBaseline = [0.799]
# order is txs, trends, posts, tweets
dogeChanges = [(0.799-0.624)/0.799, (0.799-0.487)/0.799, (0.799-0.361)/0.799, (0.799-0.418)/0.799, (0.799-0.225)/0.799, (0.799-0.077)/0.799, (0.799-0.499)/0.799]
print(["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
print(dogeChanges)
ax = plt.gca()
ax.set_ylim([0, 1])
plt.xlabel("Regressor")
plt.ylabel("Effect")
plt.title("Dogecoin")
plt.bar([2.4, 4.8, 7.2, 9.6, 12.0, 14.4, 16.8], dogeChanges, tick_label = ["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
# Out:
# ['Transactions', 'Trends', 'Reddit', 'Twitter', 'AllTrends', 'AllReddit', 'AllTwitter']
# [0.21902377972465586, 0.39048811013767215, 0.5481852315394243, 0.476846057571965, 0.7183979974968712, 0.9036295369211514, 0.3754693366708386]
# <BarContainer object of 7 artists>

# %%
shibaBaseline = [0.871]
# order is txs, trends, posts, tweets
shibaChanges = [(0.871-0.856)/0.871, (0.871-0.235)/0.871, (0.871-0.267)/0.871, (0.871-0.094)/0.871, (0.871-0.461)/0.871, (0.871-0.616)/0.871, (0.871-0.372)/0.871]
print(["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
print(shibaChanges)
ax = plt.gca()
ax.set_ylim([0, 1])
plt.xlabel("Regressor")
plt.ylabel("Effect")
plt.title("Shiba")
plt.bar([2.4, 4.8, 7.2, 9.6, 12.0, 14.4, 16.8], shibaChanges, tick_label = ["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
# Out:
# ['Transactions', 'Trends', 'Reddit', 'Twitter', 'AllTrends', 'AllReddit', 'AllTwitter']
# [0.017221584385763506, 0.730195177956372, 0.6934557979334098, 0.8920780711825488, 0.470723306544202, 0.29276693455797936, 0.5729047072330654]
# <BarContainer object of 7 artists>

# %%
import DataCleaning

# %%
bitcoinData = DataCleaning.getBitcoinData()
# Out:
# /Users/shivasaravanan/CryptoDataFull/DataCleaning.py:160: DtypeWarning: Columns (83,87,88,91) have mixed types. Specify dtype option on import or set low_memory=False.
#   bitcoinPosts = pd.read_csv("bitcoin_posts.csv")[["normal_date", "one"]]
# /Users/shivasaravanan/CryptoDataFull/DataCleaning.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoinModTrends["DayTime"] = pd.to_datetime(bitcoinModTrends["Day"])

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
for ax in axs.flat:
    ax.set_ylim([0, 1])
    ax.set_xlabel("Regressor")
    ax.set_ylabel("Effect")
axs[0, 0].set_title("Bitcoin")
axs[0, 1].set_title("Ethereum")
axs[1, 0].set_title("Dogecoin")
axs[1, 1].set_title("Shiba")
plt.style.use('dark_background')
axs[0, 0].bar([2.4, 4.8, 7.2, 9.6, 12.0, 14.4, 16.8], bitcoinChanges, tick_label = ["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
axs[0, 1].bar([2.4, 4.8, 7.2, 9.6, 12.0, 14.4, 16.8], etherChanges, tick_label = ["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
axs[1, 0].bar([2.4, 4.8, 7.2, 9.6, 12.0, 14.4, 16.8], dogeChanges, tick_label = ["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
axs[1, 1].bar([2.4, 4.8, 7.2, 9.6, 12.0, 14.4, 16.8], shibaChanges, tick_label = ["Transactions", "Trends", "Reddit", "Twitter", "AllTrends", "AllReddit", "AllTwitter"])
# Out:
# <BarContainer object of 7 artists>
