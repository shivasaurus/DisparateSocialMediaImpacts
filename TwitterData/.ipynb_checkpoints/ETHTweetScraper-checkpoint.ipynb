# %%
import os
import pandas as pd
import sys

# %%
sys.path.append("/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages")
import snscrape.modules.twitter as sntwitter

# %%
# Creating list to append tweet data to
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('(#Ethereum) filter:verified since:2020-08-01').get_items()):
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
tweets_df1
# Out:
#                        Datetime             Tweet Id  \
# 0     2022-03-14 00:32:14+00:00  1503167080878780420
# 1     2022-03-14 00:06:13+00:00  1503160535428534273
# 2     2022-03-14 00:02:19+00:00  1503159552812130309
# 3     2022-03-13 23:46:20+00:00  1503155531036430337
# 4     2022-03-13 21:56:17+00:00  1503127833853501444
# ...                         ...                  ...
# 17974 2020-08-01 19:21:34+00:00  1289642446272335872
# 17975 2020-08-01 13:01:32+00:00  1289546809002483712
# 17976 2020-08-01 11:28:00+00:00  1289523268722913282
# 17977 2020-08-01 11:26:07+00:00  1289522798142976001
# 17978 2020-08-01 11:04:11+00:00  1289517275137994752
#
#                                                     Text        Username
# 0      Abra's CEO has predicted that the price of #et...           BTCTN
# 1      ราคาบิทคอยน์วันนี้ร่วง 2.65% อยู่ที่ 37,785.3 ...     tnnthailand
# 2      The world's third largest sportswear brand @PU...        wirexapp
# 3      When Tom Brady wins another Super Bowl this ye...          Xposed
# 4      How People Actually Make #Money \n\nFrom #Cryp...  SpirosMargaris
# ...                                                  ...             ...
# 17974  OPINION: "DeFi has changed the way people thin...        CoinDesk
# 17975  One of #Ethereum's earliest projects, @AugurPr...        CoinDesk
# 17976  Hm.. So @ElrondNetwork is swapping their ERC20...    KevinLWalker
# 17977  As part of our commemoration of #Ethereum's 5t...        CoinDesk
# 17978  Anchor is a two-pronged platform for PoS token...        CoinDesk
#
# [17979 rows x 4 columns]

# %%
tweets_df1["date"] = pd.to_datetime(tweets_df1["Datetime"]).dt.date
